# %% [markdown]
# # CS 477 HW 6: Gradient Descent on MLPs
# ## Chris Tralie
#
# This is a simple test to make sure our neural network engine is able to separate the inside of a circle from the outside, which would not work with logistic regression over the two dimensions

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import IPython.display as ipd
from mlp import *
from layers import *
from losses import *

# %%
model = MLP(10, logistic_loss_deriv)
model.add_layer(20, leaky_relu, leaky_relu_deriv)
model.add_layer(5, leaky_relu, leaky_relu_deriv, "special_start")
model.add_layer(8, leaky_relu, leaky_relu_deriv)
model.add_layer(7, leaky_relu, leaky_relu_deriv, "special_end")
model.add_layer(1, leaky_relu, leaky_relu_deriv)
x = np.random.randn(10)
y = model.forward(x)
print(y.shape)
# Show how to start/end in the middle of the network
x = np.random.randn(20)
y = model.forward(x, start="special_start", end="special_end")
print(y.shape)
# Out:
# (1,)
# (7,)

# %% [markdown]
# First, let's generate the data

# %%
def get_disc_points(N):
    X = np.random.randn(N, 2)
    d = np.sqrt(np.sum(X**2, axis=1))
    ys = np.array(d < 1, dtype=float)
    X[ys == 0, :] *= 1.1 # Put a small gap between inner and outer points
    return X, ys

np.random.seed(0)
X, ys = get_disc_points(1000)
plt.scatter(X[ys==0, 0], X[ys==0, 1])
plt.scatter(X[ys==1, 0], X[ys==1, 1])
plt.axis("equal")
plt.title("Initial Disc Data")
# Out:
# Text(0.5, 1.0, 'Initial Disc Data')

# %% [markdown]
# Now let's setup a neural network and train it!  We'll put 100 neurons in the first hidden layer, followed by 2 neurons, followed by a single neuron with the logistic activation.  Since the last hidden layer has 2 neurons, we can the coordinates on the data mapped through it to see how well it's being separated

# %%
plot_animation=True
np.random.seed(0)

nn = MLP(2, logistic_est_loss_deriv) # Input is in 2 dimensions, and we want to use logistic loss
nn.add_layer(100,  leaky_relu, leaky_relu_deriv, name="layer1") # First layer is 100 dimensions with a leaky ReLU
nn.add_layer(2, leaky_relu, leaky_relu_deriv, name="layer2") # Second layer is 2 dimensions with a leaky ReLU
nn.add_layer(1, logistic, None, name="lastlayer") # Last layer is the logistic function.  Its derivative is handled separately

n_epochs = 100
alpha = 0.001
losses = []

fig = plt.figure(figsize=(12, 6))
frames = []
for epoch in range(n_epochs):
    loss = 0
    num_correct = 0
    X1 = []
    X2 = []
    for k in range(X.shape[0]):
        y_est = nn.forward(X[k, :])
        num_correct += (np.round(y_est) == ys[k])
        loss += logistic_est_loss(y_est, ys[k])
        xy = nn.forward(X[k, :], end="layer2")
        if ys[k] == 0:
            X1.append(xy)
        else:
            X2.append(xy)
    print("Epoch {} Loss {} Accuracy {}".format(epoch, loss, num_correct[0]/X.shape[0]))
    losses.append(loss)
    X1 = np.array(X1)
    X2 = np.array(X2)


    # Plot Result
    # Get the 2D linear separator from the weights/bias in the last layer
    #a, b = nn.layers[-1]["W"].flatten() 
    #c = nn.layers[-1]["b"][0]
    plt.subplot(121)
    plot = [plt.scatter(X1[:, 0], X1[:, 1], c='C0')]
    plot += [plt.scatter(X2[:, 0], X2[:, 1], c='C1')]
    plt.gca().set_facecolor("white")
    plot.append(plt.text(0.5, 1.01, "Epoch {} Accuracy {:.3f}".format(epoch, num_correct[0]/X.shape[0]),
                        horizontalalignment='center', verticalalignment='bottom',
                        transform=plt.gca().transAxes, size='xx-large'))
    
    plt.subplot(122)
    plot += plt.plot(losses, c='C0')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.xlim([0, n_epochs])
    plt.ylim([0, np.max(losses)])
    plot.append(plt.text(0.5, 1.01, "Loss {:.3f}".format(loss[0]),
                        horizontalalignment='center', verticalalignment='bottom',
                        transform=plt.gca().transAxes, size='xx-large'))
    plt.gca().set_facecolor("white")
    frames.append(plot)
    
    # Stochastic gradient descent
    for k in np.random.permutation(X.shape[0]):
        nn.backward(X[k, :], ys[k])
        nn.step(alpha)
        nn.zero_grad()

ani = animation.ArtistAnimation(fig, frames, interval=200, blit=True, repeat_delay=1000)
ani.save("result.gif", dpi=200)
# Out:
# Epoch 0 Loss [675.70343765] Accuracy 0.593
# Epoch 1 Loss [675.48034189] Accuracy 0.593
# Epoch 2 Loss [675.3517789] Accuracy 0.593
# Epoch 3 Loss [675.24759188] Accuracy 0.593
# Epoch 4 Loss [675.13010629] Accuracy 0.593
# Epoch 5 Loss [675.01489185] Accuracy 0.593
# Epoch 6 Loss [674.86548543] Accuracy 0.593
# Epoch 7 Loss [674.71791304] Accuracy 0.593
# Epoch 8 Loss [674.53269756] Accuracy 0.593
# Epoch 9 Loss [674.33179114] Accuracy 0.593
# Epoch 10 Loss [674.11256208] Accuracy 0.593
# Epoch 11 Loss [673.83796862] Accuracy 0.593
# Epoch 12 Loss [673.54804798] Accuracy 0.593
# Epoch 13 Loss [673.17423825] Accuracy 0.593
# Epoch 14 Loss [672.75681489] Accuracy 0.593
# Epoch 15 Loss [672.27802823] Accuracy 0.593
# Epoch 16 Loss [671.73324044] Accuracy 0.593
# Epoch 17 Loss [671.04873573] Accuracy 0.593
# Epoch 18 Loss [670.28062565] Accuracy 0.593
# Epoch 19 Loss [669.3538542] Accuracy 0.593
# Epoch 20 Loss [668.2917658] Accuracy 0.593
# Epoch 21 Loss [667.02387339] Accuracy 0.593
# Epoch 22 Loss [665.51590976] Accuracy 0.593
# Epoch 23 Loss [663.66841385] Accuracy 0.593
# Epoch 24 Loss [661.47800971] Accuracy 0.593
# Epoch 25 Loss [659.10371655] Accuracy 0.593
# Epoch 26 Loss [656.55297023] Accuracy 0.593
# Epoch 27 Loss [651.89204313] Accuracy 0.593
# Epoch 28 Loss [647.72947613] Accuracy 0.593
# Epoch 29 Loss [641.16242954] Accuracy 0.593
# Epoch 30 Loss [634.03341723] Accuracy 0.593
# Epoch 31 Loss [624.95662606] Accuracy 0.593
# Epoch 32 Loss [614.02308024] Accuracy 0.593
# Epoch 33 Loss [601.29933563] Accuracy 0.593
# Epoch 34 Loss [590.35941011] Accuracy 0.593
# Epoch 35 Loss [578.91826231] Accuracy 0.825
# Epoch 36 Loss [538.00211339] Accuracy 0.848
# Epoch 37 Loss [508.90780106] Accuracy 0.848
# Epoch 38 Loss [478.85257134] Accuracy 0.837
# Epoch 39 Loss [440.54995905] Accuracy 0.914
# Epoch 40 Loss [418.09667833] Accuracy 0.893
# Epoch 41 Loss [365.20125338] Accuracy 0.942
# Epoch 42 Loss [331.81115644] Accuracy 0.938
# Epoch 43 Loss [294.54637157] Accuracy 0.961
# Epoch 44 Loss [265.70668835] Accuracy 0.961
# Epoch 45 Loss [237.66378267] Accuracy 0.975
# Epoch 46 Loss [216.42125819] Accuracy 0.977
# Epoch 47 Loss [194.56245114] Accuracy 0.987
# Epoch 48 Loss [187.54619291] Accuracy 0.957
# Epoch 49 Loss [169.81555961] Accuracy 0.97
# Epoch 50 Loss [148.87148428] Accuracy 0.993
# Epoch 51 Loss [139.47942723] Accuracy 0.986
# Epoch 52 Loss [133.86039948] Accuracy 0.989
# Epoch 53 Loss [121.96502393] Accuracy 0.993
# Epoch 54 Loss [112.54664732] Accuracy 0.998
# Epoch 55 Loss [106.2386041] Accuracy 0.998
# Epoch 56 Loss [99.93542807] Accuracy 1.0
# Epoch 57 Loss [96.90934556] Accuracy 0.998
# Epoch 58 Loss [90.00105365] Accuracy 1.0
# Epoch 59 Loss [87.27329665] Accuracy 0.999
# Epoch 60 Loss [81.49279514] Accuracy 1.0
# Epoch 61 Loss [77.60538886] Accuracy 1.0
# Epoch 62 Loss [74.69313458] Accuracy 1.0
# Epoch 63 Loss [71.05697697] Accuracy 1.0
# Epoch 64 Loss [69.61130685] Accuracy 0.999
# Epoch 65 Loss [66.35653792] Accuracy 0.999
# Epoch 66 Loss [63.49437915] Accuracy 1.0
# Epoch 67 Loss [60.87653169] Accuracy 1.0
# Epoch 68 Loss [58.78844906] Accuracy 1.0
# Epoch 69 Loss [57.18317443] Accuracy 1.0
# Epoch 70 Loss [54.95107223] Accuracy 1.0
# Epoch 71 Loss [53.75566834] Accuracy 1.0
# Epoch 72 Loss [51.48049845] Accuracy 1.0
# Epoch 73 Loss [51.86288899] Accuracy 1.0
# Epoch 74 Loss [49.24658327] Accuracy 0.999
# Epoch 75 Loss [47.9156903] Accuracy 0.999
# Epoch 76 Loss [46.09724014] Accuracy 1.0
# Epoch 77 Loss [44.92204753] Accuracy 1.0
# Epoch 78 Loss [43.29392037] Accuracy 1.0
# Epoch 79 Loss [42.34719326] Accuracy 1.0
# Epoch 80 Loss [41.17850644] Accuracy 1.0
# Epoch 81 Loss [41.06228969] Accuracy 1.0
# Epoch 82 Loss [39.11315812] Accuracy 1.0
# Epoch 83 Loss [38.6443471] Accuracy 0.999
# Epoch 84 Loss [37.3623807] Accuracy 1.0
# Epoch 85 Loss [36.43983144] Accuracy 1.0
# Epoch 86 Loss [35.62538397] Accuracy 1.0
# Epoch 87 Loss [34.98448289] Accuracy 1.0
# Epoch 88 Loss [34.72044961] Accuracy 1.0
# Epoch 89 Loss [34.21182212] Accuracy 0.999
# Epoch 90 Loss [38.72364209] Accuracy 0.999
# Epoch 91 Loss [34.77491997] Accuracy 1.0
# Epoch 92 Loss [31.34503612] Accuracy 1.0
# Epoch 93 Loss [31.50911868] Accuracy 1.0
# Epoch 94 Loss [33.21168593] Accuracy 1.0
# Epoch 95 Loss [29.74180031] Accuracy 1.0
# Epoch 96 Loss [29.32228126] Accuracy 1.0
# Epoch 97 Loss [29.22875657] Accuracy 0.999
# Epoch 98 Loss [30.50763345] Accuracy 1.0
# Epoch 99 Loss [27.53738041] Accuracy 1.0
# MovieWriter ffmpeg unavailable; using Pillow instead.
